# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/12eZx8jw4P_UKozmXYUGsC67X8T6kJnxL">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />
#     Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_lite/tflite_c04_exercise_convert_model_to_tflite_solution.ipynb">
#     <img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />
#     View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# #Environment Setup

# %% [markdown]
# ## Import Dependencies

# %%
"""
# !python --version
# !pip install --upgrade setuptool
#!pip uninstall tensorflow
# !pip install keras==2.2.4
# !pip install tensorflow==1.15
# !pip install h5py==2.10.0
"""
# Out:
# '\n!python --version\n!pip install --upgrade setuptool\n#!pip uninstall tensorflow\n!pip install keras==2.2.4\n!pip install tensorflow==1.15\n!pip install h5py==2.10.0\n'

# %%
import os
import csv
import cv2
import matplotlib.pyplot as plt
import random
import pprint

import numpy as np
from numpy import expand_dims

#%tensorflow_version 1.x
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.logging.ERROR)

from keras import backend as K
from keras.models import Model, Sequential
from keras.models import load_model
from keras.layers import Dense, GlobalAveragePooling2D, MaxPooling2D, Lambda, Cropping2D
from keras.layers.convolutional import Convolution2D
from keras.layers.core import Flatten, Dense, Dropout, SpatialDropout2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array 
#from google.colab.patches import cv2_imshow
  
import sklearn
from sklearn.model_selection import train_test_split
import pandas as pd
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

print("Tensorflow Version:",tf.__version__)
print("Tensorflow Keras Version:",tf.keras.__version__)
print("Eager mode: ", tf.executing_eagerly())
# Out:
# WARNING:tensorflow:From C:\Users\master\AppData\Local\Temp\ipykernel_12404\1416451443.py:13: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
# Using TensorFlow backend.
# Tensorflow Version: 1.15.0
# Tensorflow Keras Version: 2.2.4-tf
# Eager mode:  False

# %% [markdown]
# ## Confirm TensorFlow can see the GPU
#
# Simply select "GPU" in the Accelerator drop-down in Notebook Settings (either through the Edit menu or the command palette at cmd/ctrl-shift-P).

# %%
device_name = tf.test.gpu_device_name()

if device_name != '/device:GPU:0':
  #raise SystemError('GPU device not found')
  print('GPU device not found')
else:
  print('Found GPU at: {}'.format(device_name))
# Out:
# GPU device not found

# %% [markdown]
# # Load Dataset

# %% [markdown]
# ## Download and Extract the Dataset

# %%
# Download the dataset
#!curl -O https://selbystorage.s3-us-west-2.amazonaws.com/research/office_2/office_2.tar.gz

# %%
#data_set = 'office_2'
#tar_file = data_set + '.tar.gz'

# Unzip the .tgz file
# -x for extract
# -v for verbose 
# -z for gnuzip
# -f for file (should come at last just before file name)
# -C to extract the zipped contents to a different directory
#!tar -xvzf $tar_file

# %% [markdown]
# ## Parse CSV File

# %%
import pandas as pd
#from google.colab import drive
#drive.mount('/content/drive')

#%cd C:\Users\user\Desktop\Colab_RC
#!unzip "white_inner.zip" -d "white_inner"

data_set = 'C:/Users/master/Desktop/study/label_data/RC'

# Define path to csv file
csv_path = 'C:/Users/master/Desktop/study/label_data/RC/interpolated.csv'

# Load the CSV file into a pandas dataframe
df = pd.read_csv(csv_path, sep=",")

# Print the dimensions
print("Dataset Dimensions:")
print(df.shape)

# Print the first 5 lines of the dataframe for review
print("\nDataset Summary:")
df.head(5)
# Out:
# Dataset Dimensions:
# (26870, 8)
#
# Dataset Summary:
#                            index     timestamp  width  height  frame_id  \
# 0  2023-01-20 05:43:34.429305076  1.674193e+18    320     240       NaN
# 1  2023-01-20 05:43:34.529125928  1.674193e+18    320     240       NaN
# 2  2023-01-20 05:43:34.628747940  1.674193e+18    320     240       NaN
# 3  2023-01-20 05:43:34.730494976  1.674193e+18    320     240       NaN
# 4  2023-01-20 05:43:34.830076932  1.674193e+18    320     240       NaN
#
#                          filename  angle  speed
# 0  center/1674193414429305076.jpg    0.0    0.0
# 1  center/1674193414529125928.jpg    0.0    0.0
# 2  center/1674193414628747940.jpg    0.0    0.0
# 3  center/1674193414730494976.jpg    0.0    0.0
# 4  center/1674193414830076932.jpg    0.0    0.0

# %%
gt = os.path.join(data_set, "center")
gt_img = os.listdir(gt)
print(len(gt_img))

for csv_name in df['filename']:
    n = 0
    for gt_name in gt_img:
        name = 'center/' + gt_name
        if csv_name == name:
            # df.replace({'filename':csv_name}, gt_name)
            break
        n += 1
        if n == len(gt_img):
            df = df[df.filename != csv_name]

print("Dataset Dimensions:")
print(df.shape)

print("\nDataset Summary:")
df.head(5)
# Out:
# 8826
# Dataset Dimensions:
# (8826, 8)
#
# Dataset Summary:
#                             index     timestamp  width  height  frame_id  \
# 25  2023-01-20 05:43:36.927381038  1.674193e+18    320     240       NaN
# 35  2023-01-20 05:43:37.927217006  1.674193e+18    320     240       NaN
# 47  2023-01-20 05:43:39.132527112  1.674193e+18    320     240       NaN
# 48  2023-01-20 05:43:39.228671073  1.674193e+18    320     240       NaN
# 49  2023-01-20 05:43:39.328280925  1.674193e+18    320     240       NaN
#
#                           filename  angle  speed
# 25  center/1674193416927381038.jpg    0.0    0.0
# 35  center/1674193417927217006.jpg    0.0    0.0
# 47  center/1674193419132527112.jpg    0.0    0.0
# 48  center/1674193419228671073.jpg    0.0    0.0
# 49  center/1674193419328280925.jpg    0.0    0.0

# %% [markdown]
# # Clean and Pre-process the Dataset

# %%
print(csv_path)
# Out:
# C:/Users/master/Desktop/study/label_data/RC/interpolated.csv

# %% [markdown]
# ## Remove Unneccessary Columns

# %%
# Remove 'index' and 'frame_id' columns 
df.drop(['index','frame_id'],axis=1,inplace=True)

# Verify new dataframe dimensions
print("Dataset Dimensions:")
print(df.shape)

# Print the first 5 lines of the new dataframe for review
print("\nDataset Summary:")
df.head(5)
# Out:
# Dataset Dimensions:
# (8826, 6)
#
# Dataset Summary:
#        timestamp  width  height                        filename  angle  speed
# 25  1.674193e+18    320     240  center/1674193416927381038.jpg    0.0    0.0
# 35  1.674193e+18    320     240  center/1674193417927217006.jpg    0.0    0.0
# 47  1.674193e+18    320     240  center/1674193419132527112.jpg    0.0    0.0
# 48  1.674193e+18    320     240  center/1674193419228671073.jpg    0.0    0.0
# 49  1.674193e+18    320     240  center/1674193419328280925.jpg    0.0    0.0

# %% [markdown]
# ## Detect Missing Data

# %%
# Detect Missing Values
print("Any Missing Values?: {}".format(df.isnull().values.any()))

# Total Sum
print("\nTotal Number of Missing Values: {}".format(df.isnull().sum().sum()))

# Sum Per Column
print("\nTotal Number of Missing Values per Column:")
print(df.isnull().sum())
# Out:
# Any Missing Values?: False
#
# Total Number of Missing Values: 0
#
# Total Number of Missing Values per Column:
# timestamp    0
# width        0
# height       0
# filename     0
# angle        0
# speed        0
# dtype: int64

# %% [markdown]
# ## Remove Zero Throttle Values

# %%
# Determine if any throttle values are zeroes
print("Any 0 throttle values?: {}".format(df['speed'].eq(0).any()))

# Determine number of 0 throttle values:
print("\nNumber of 0 throttle values: {}".format(df['speed'].eq(0).sum()))

# Remove rows with 0 throttle values
if df['speed'].eq(0).any():
  df = df.query('speed != 0')
  
  # Reset the index
  df.reset_index(inplace=True,drop=True)
  
# Verify new dataframe dimensions
print("\nNew Dataset Dimensions:")
print(df.shape)
df.head(5)
# Out:
# Any 0 throttle values?: True
#
# Number of 0 throttle values: 1607
#
# New Dataset Dimensions:
# (7219, 6)
#       timestamp  width  height                        filename  angle  speed
# 0  1.674193e+18    320     240  center/1674193433328696966.jpg    0.0    2.0
# 1  1.674193e+18    320     240  center/1674193433428157091.jpg    0.0    2.0
# 2  1.674193e+18    320     240  center/1674193433528307914.jpg    0.0    2.0
# 3  1.674193e+18    320     240  center/1674193433827578067.jpg    0.0    2.0
# 4  1.674193e+18    320     240  center/1674193433928630113.jpg    0.0    2.0

# %% [markdown]
# ## View Label Statistics

# %%
df["angle"] = df["angle"] * 10
print("\nNew Dataset Dimensions:")
print(df.shape)
df.head(100)
# Out:
# New Dataset Dimensions:
# (7219, 6)
#        timestamp  width  height                        filename     angle  \
# 0   1.674193e+18    320     240  center/1674193433328696966.jpg  0.000000
# 1   1.674193e+18    320     240  center/1674193433428157091.jpg  0.000000
# 2   1.674193e+18    320     240  center/1674193433528307914.jpg  0.000000
# 3   1.674193e+18    320     240  center/1674193433827578067.jpg  0.000000
# 4   1.674193e+18    320     240  center/1674193433928630113.jpg  0.000000
# ..           ...    ...     ...                             ...       ...
# 95  1.674193e+18    320     240  center/1674193462227756023.jpg  0.815464
# 96  1.674193e+18    320     240  center/1674193462428308963.jpg  0.050437
# 97  1.674193e+18    320     240  center/1674193462727788925.jpg  0.000000
# 98  1.674193e+18    320     240  center/1674193462829145908.jpg  0.000000
# 99  1.674193e+18    320     240  center/1674193462927901029.jpg  0.000000
#
#        speed
# 0   2.000000
# 1   2.000000
# 2   2.000000
# 3   2.000000
# 4   2.000000
# ..       ...
# 95  0.583818
# 96  0.583818
# 97  0.650610
# 98  0.667112
# 99  0.667112
#
# [100 rows x 6 columns]

# %%
# Steering Command Statistics
print("\nSteering Command Statistics:")
print(df['angle'].describe())

print("\nThrottle Command Statistics:")
# Throttle Command Statistics
print(df['speed'].describe())
# Out:
# Steering Command Statistics:
# count    7219.000000
# mean        0.119712
# std         0.881400
# min        -3.400000
# 25%         0.000000
# 50%         0.000000
# 75%         0.377532
# max         3.400000
# Name: angle, dtype: float64
#
# Throttle Command Statistics:
# count    7219.000000
# mean        0.534774
# std         0.113111
# min         0.000184
# 25%         0.479685
# 50%         0.542140
# 75%         0.583818
# max         2.000000
# Name: speed, dtype: float64

# %% [markdown]
# ## View Histogram of Steering Commands

# %%
import numpy as np
import matplotlib.pyplot as plt
#@title Select the number of histogram bins

num_bins = 28 #@param {type:"slider", min:5, max:50, step:1}

hist, bins = np.histogram(df['angle'], num_bins)
center = (bins[:-1]+ bins[1:]) * 0.5
plt.bar(center, hist, width=0.05)
#plt.plot((np.min(df['angle']), np.max(df['angle'])), (samples_per_bin, samples_per_bin))
# Out:
# <BarContainer object of 28 artists>

# %%
# Normalize the histogram (150-300 for RBG)
#@title Normalize the Histogram { run: "auto" }
hist = True #@param {type:"boolean"}

remove_list = []
samples_per_bin = 200

if hist:
  for j in range(num_bins):
    list_ = []
    for i in range(len(df['angle'])):
      if df.loc[i,'angle'] >= bins[j] and df.loc[i,'angle'] <= bins[j+1]:
        list_.append(i)
    random.shuffle(list_)
    list_ = list_[samples_per_bin:]
    remove_list.extend(list_)

  print('removed:', len(remove_list))
  df.drop(df.index[remove_list], inplace=True)
  df.reset_index(inplace=True)
  df.drop(['index'],axis=1,inplace=True)
  print('remaining:', len(df))
  
  hist, _ = np.histogram(df['angle'], (num_bins))
  plt.bar(center, hist, width=0.05)
  plt.plot((np.min(df['angle']), np.max(df['angle'])), (samples_per_bin, samples_per_bin))
# Out:
# removed: 8923
# remaining: 1773

# %% [markdown]
# ## View a Sample Image

# %%
# View a Single Image 
index = random.randint(0,df.shape[0]-1)

img_name = data_set + '/' + df.loc[index,'filename']
print(img_name)
angle = df.loc[index,'angle']

center_image = cv2.imread(img_name)
center_image_mod = cv2.resize(center_image, (320,180))
center_image_mod = cv2.cvtColor(center_image_mod,cv2.COLOR_RGB2BGR)
#center_image_mod = cv2.cvtColor(center_image,cv2.COLOR_RGB2BGR)

# Crop the image
height_min = 75 
height_max = center_image_mod.shape[0]
width_min = 0
width_max = center_image_mod.shape[1]

crop_img = center_image_mod[height_min:height_max, width_min:width_max]

plt.subplot(2,1,1)
plt.imshow(center_image_mod)
plt.grid(False)
plt.xlabel('angle: {:.2}'.format(angle))
plt.show() 

plt.subplot(2,1,2)
plt.imshow(crop_img)
plt.grid(False)
plt.xlabel('angle: {:.2}'.format(angle))
plt.show()
# Out:
# C:/Users/master/Desktop/study/label_data/RC/center/1674635147334106922.jpg

# %% [markdown]
# ## View Multiple Images

# %%
# Number of Images to Display
num_images = 4

# Display the images
i = 0
for i in range (i,num_images):
    index = random.randint(0,df.shape[0]-1)
    image_path = df.loc[index,'filename']
    angle = df.loc[index,'angle']
    img_name = data_set + '/' + image_path
    image = cv2.imread(img_name)
    image = cv2.resize(image, (320,180))
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    plt.subplot(int(num_images/2),int(num_images/2),i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel('angle: {:.3}'.format(angle))
    i += 1

# %% [markdown]
# # Split the Dataset

# %% [markdown]
# ## Define an ImageDataGenerator to Augment Images
#
# [Exploring Image Data Augmentation with Keras and Tensorflow](https://towardsdatascience.com/exploring-image-data-augmentation-with-eras-and-tensorflow-a8162d89b844
# )

# %%
# Create image data augmentation generator and choose augmentation types
datagen = ImageDataGenerator(
                             #rotation_range=20,
                             zoom_range=0.15,
                             #width_shift_range=0.1,
                             #height_shift_range=0.2,
                             #shear_range=10,
                             brightness_range=[0.5,1.0],
                          	 #horizontal_flip=True,
                             #vertical_flip=True,
                             #channel_shift_range=100.0,
                             fill_mode="reflect")

# %% [markdown]
# ## View Image Augmentation Examples

# %%
# load the image
index = random.randint(0,df.shape[0]-1)

img_name = data_set + '/' + df.loc[index,'filename']
original_image = cv2.imread(img_name)
original_image = cv2.cvtColor(original_image,cv2.COLOR_RGB2BGR)
original_image = cv2.resize(original_image, (320,180))
label = df.loc[index,'angle']

# convert to numpy array
data = img_to_array(original_image)

# expand dimension to one sample
test = expand_dims(data, 0)

# prepare iterator
it = datagen.flow(test, batch_size=1)

# generate batch of images
batch = it.next()

# convert to unsigned integers for viewing
image_aug = batch[0].astype('uint8')

print("Augmenting a Single Image: \n")

plt.subplot(2,1,1)
plt.imshow(original_image)
plt.grid(False)
plt.xlabel('angle: {:.2}'.format(label))
plt.show() 

plt.subplot(2,1,2)
plt.imshow(image_aug)
plt.grid(False)
plt.xlabel('angle: {:.2}'.format(label))
plt.show() 

print("Multiple Augmentations: \n")
# generate samples and plot
for i in range(0,num_images):
	# define subplot
	plt.subplot(int(num_images/2),int(num_images/2),i+1)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	plt.imshow(image)
# show the figure
plt.show()
# Out:
# Augmenting a Single Image:
# Multiple Augmentations:

# %% [markdown]
# ## Define a Data Generator

# %%
def generator(samples, batch_size=32, aug=0):
    num_samples = len(samples)

    while 1:  # Loop forever so the generator never terminates
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset + batch_size]

            #print(batch_samples)
            images = []
            angles = []
            for batch_sample in batch_samples:
                if batch_sample[5] != "filename":
                    name = data_set + '/' + batch_sample[3]
                    center_image = cv2.imread(name)
                    center_image = cv2.cvtColor(center_image,cv2.COLOR_RGB2BGR)
                    center_image = cv2.resize(
                        center_image,
                        (320,180))  #resize from 720x1280 to 180x320
                    angle = float(batch_sample[4])
                    if not aug:
                      images.append(center_image)
                      angles.append(angle)
                    else:
                        data = img_to_array(center_image)
                        sample = expand_dims(data, 0)
                        it = datagen.flow(sample, batch_size=1)
                        batch = it.next()
                        image_aug = batch[0].astype('uint8')
                        if random.random() < .5:
                          image_aug = np.fliplr(image_aug)
                          angle = -1 * angle
                        images.append(image_aug)
                        angles.append(angle)

            X_train = np.array(images)
            y_train = np.array(angles)

            yield sklearn.utils.shuffle(X_train, y_train)

# %% [markdown]
# ## Split the Dataset

# %%
samples = []

samples = df.values.tolist()

sklearn.utils.shuffle(samples)
train_samples, validation_samples = train_test_split(samples, test_size=0.2)

print("Number of traing samples: ", len(train_samples))
print("Number of validation samples: ", len(validation_samples))
# Out:
# Number of traing samples:  1418
# Number of validation samples:  355

# %% [markdown]
# ## Define Training and Validation Data Generators

# %%
batch_size_value = 32
img_aug = 0

train_generator = generator(train_samples, batch_size=batch_size_value, aug=img_aug)
validation_generator = generator(
    validation_samples, batch_size=batch_size_value, aug=0)

# %% [markdown]
# # Compile and Train the Model

# %% [markdown]
# ## Build the Model

# %%
# Initialize the model
model = Sequential()

# trim image to only see section with road
# (top_crop, bottom_crop), (left_crop, right_crop)
model.add(Cropping2D(cropping=((height_min,0), (width_min,0)), input_shape=(180,320,3)))

# Preprocess incoming data, centered around zero with small standard deviation
model.add(Lambda(lambda x: (x / 255.0) - 0.5))

# Nvidia model
model.add(Convolution2D(24, (5, 5), activation="relu", name="conv_1", strides=(2, 2)))
# """"""
model.add(Convolution2D(36, (5, 5), activation="relu", name="conv_2", strides=(2, 2)))
model.add(Convolution2D(48, (5, 5), activation="relu", name="conv_3", strides=(2, 2)))
model.add(SpatialDropout2D(.5, dim_ordering='default'))

model.add(Convolution2D(64, (3, 3), activation="relu", name="conv_4", strides=(1, 1)))
model.add(Convolution2D(64, (3, 3), activation="relu", name="conv_5", strides=(1, 1)))

model.add(Flatten())

model.add(Dense(1164))
model.add(Dropout(.5))
model.add(Dense(100, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(50, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(10, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(1))

model.compile(loss='mse', optimizer=Adam(lr=0.001), metrics=['mse','mae','mape','cosine'])

# Print model sumamry
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cropping2d_1 (Cropping2D)    (None, 105, 320, 3)       0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 105, 320, 3)       0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 51, 158, 24)       1824
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 24, 77, 36)        21636
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 10, 37, 48)        43248
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 10, 37, 48)        0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 8, 35, 64)         27712
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 6, 33, 64)         36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12672)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1164)              14751372
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1164)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               116500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 15,004,791
# Trainable params: 15,004,791
# Non-trainable params: 0
# _________________________________________________________________
# c:\Users\master\anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `SpatialDropout2D` call to the Keras 2 API: `SpatialDropout2D(0.5, data_format=None)`

# %% [markdown]
# ## Setup Checkpoints

# %%
# checkpoint
model_path = 'C:/Users/master/Desktop/study/label_data/RC/model'

#!if [ -d $model_path ]; then echo 'Directory Exists'; else mkdir $model_path; fi

filepath = model_path + "/weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto', period=1)

# %% [markdown]
# ## Setup Early Stopping to Prevent Overfitting

# %%
# The patience parameter is the amount of epochs to check for improvement
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ## Reduce Learning Rate When a Metric has Stopped Improving

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)

# %% [markdown]
# ## Setup Tensorboard
#
# [Tensorboard Documentation](https://keras.io/callbacks/#tensorboard)

# %%
# Clear any logs from previous runs
#!rm -rf ./Graph/ 


# Launch Tensorboard
#!pip install -U tensorboardcolab
# from tensorflow.keras.callbacks import tensorboard
# from tensorboardcolab import *
from keras.callbacks import TensorBoard
# from tensorboard import *
tbc = TensorBoard()

# Configure the Tensorboard Callback
tbCallBack = TensorBoard(log_dir='./Graph', 
                        histogram_freq=1,
                        write_graph=True,
                        write_grads=True,
                        write_images=True,
                        batch_size=batch_size_value,
                        update_freq='epoch')

# %% [markdown]
# ## Load Existing Model

# %%
load = False #@param {type:"boolean"}

if load:
  # Returns a compiled model identical to the previous one
  #!curl -O https://selbystorage.s3-us-west-2.amazonaws.com/research/office_2/model.h5
  #!mv model.h5 model/
  #model_path_full = model_path + '/' + 'model.h5'
  model_path_full = 'RC_gt_2.h5'
  model = load_model(model_path_full)
  print("Loaded previous model: {} \n".format(model_path_full))
else:
  print("No previous model loaded \n")
# Out:
# No previous model loaded

# %%
STEP_SIZE_TRAIN = (len(train_samples) / batch_size_value)
STEP_SIZE_VALID = (len(validation_samples) / batch_size_value)

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %% [markdown]
# ## Train the Model

# %%
# Define step sizes
STEP_SIZE_TRAIN = (len(train_samples) / batch_size_value)
STEP_SIZE_VALID = (len(validation_samples) / batch_size_value)

# Define number of epochs
n_epoch = 100 

# Define callbacks
# callbacks_list = [TensorBoardColabCallback(tbc)]
# callbacks_list = [TensorBoardColabCallback(tbc), early_stop]
# callbacks_list = [TensorBoardColabCallback(tbc), early_stop, checkpoint]
callbacks_list = [TensorBoard(tbc), early_stop, checkpoint, reduce_lr]

# Fit the model
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#     try:
#         # Currently, memory growth needs to be the same across GPUs
#         for gpu in gpus:
#             tf.config.experimental.set_memory_growth(gpu, True)
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#     except RuntimeError as e:
#         # Memory growth must be set before GPUs have been initialized
#         print(e)
        
history_object = model.fit_generator(
    generator=train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VALID,
    #callbacks=callbacks_list,
    use_multiprocessing=False,
    epochs=n_epoch)
# Out:
# Epoch 1/100
# 45/44 [==============================] - 43s 954ms/step - loss: 3.1608 - mean_squared_error: 3.1608 - mean_absolute_error: 1.4804 - mean_absolute_percentage_error: 374337.4278 - cosine_proximity: -0.2239 - val_loss: 2.8623 - val_mean_squared_error: 2.8623 - val_mean_absolute_error: 1.3984 - val_mean_absolute_percentage_error: 118019.2065 - val_cosine_proximity: -0.4113
# Epoch 2/100
# 45/44 [==============================] - 28s 619ms/step - loss: 2.7997 - mean_squared_error: 2.7997 - mean_absolute_error: 1.3673 - mean_absolute_percentage_error: 1077210.0270 - cosine_proximity: -0.4186 - val_loss: 0.8940 - val_mean_squared_error: 0.8940 - val_mean_absolute_error: 0.7234 - val_mean_absolute_percentage_error: 23215.5271 - val_cosine_proximity: -0.9070
# Epoch 3/100
# 45/44 [==============================] - 27s 610ms/step - loss: 1.9730 - mean_squared_error: 1.9730 - mean_absolute_error: 1.0850 - mean_absolute_percentage_error: 1134594.9187 - cosine_proximity: -0.7275 - val_loss: 0.8999 - val_mean_squared_error: 0.8999 - val_mean_absolute_error: 0.7329 - val_mean_absolute_percentage_error: 1059215.6868 - val_cosine_proximity: -0.9690
# Epoch 4/100
# 45/44 [==============================] - 27s 607ms/step - loss: 1.4867 - mean_squared_error: 1.4867 - mean_absolute_error: 0.9334 - mean_absolute_percentage_error: 1287122.9358 - cosine_proximity: -0.8438 - val_loss: 0.9263 - val_mean_squared_error: 0.9263 - val_mean_absolute_error: 0.7434 - val_mean_absolute_percentage_error: 906468.4409 - val_cosine_proximity: -0.9634
# Epoch 5/100
# 45/44 [==============================] - 27s 609ms/step - loss: 1.4220 - mean_squared_error: 1.4220 - mean_absolute_error: 0.8907 - mean_absolute_percentage_error: 2115229.5528 - cosine_proximity: -0.8454 - val_loss: 0.5312 - val_mean_squared_error: 0.5312 - val_mean_absolute_error: 0.5622 - val_mean_absolute_percentage_error: 1159074.5760 - val_cosine_proximity: -0.9577
# Epoch 6/100
# 45/44 [==============================] - 27s 608ms/step - loss: 1.2566 - mean_squared_error: 1.2566 - mean_absolute_error: 0.8308 - mean_absolute_percentage_error: 2012601.2073 - cosine_proximity: -0.8843 - val_loss: 0.7115 - val_mean_squared_error: 0.7115 - val_mean_absolute_error: 0.6560 - val_mean_absolute_percentage_error: 984065.3761 - val_cosine_proximity: -0.9746
# Epoch 7/100
# 45/44 [==============================] - 28s 613ms/step - loss: 1.1806 - mean_squared_error: 1.1806 - mean_absolute_error: 0.8099 - mean_absolute_percentage_error: 1456124.6843 - cosine_proximity: -0.8900 - val_loss: 0.8867 - val_mean_squared_error: 0.8867 - val_mean_absolute_error: 0.7348 - val_mean_absolute_percentage_error: 589139.2210 - val_cosine_proximity: -0.9803
# Epoch 8/100
# 45/44 [==============================] - 29s 655ms/step - loss: 1.0958 - mean_squared_error: 1.0958 - mean_absolute_error: 0.7741 - mean_absolute_percentage_error: 2072858.3346 - cosine_proximity: -0.9011 - val_loss: 0.4972 - val_mean_squared_error: 0.4972 - val_mean_absolute_error: 0.5383 - val_mean_absolute_percentage_error: 1182296.6631 - val_cosine_proximity: -0.9746
# Epoch 9/100
# 45/44 [==============================] - 29s 637ms/step - loss: 1.1585 - mean_squared_error: 1.1585 - mean_absolute_error: 0.8009 - mean_absolute_percentage_error: 1410699.8906 - cosine_proximity: -0.8968 - val_loss: 0.3940 - val_mean_squared_error: 0.3940 - val_mean_absolute_error: 0.4730 - val_mean_absolute_percentage_error: 1209800.5956 - val_cosine_proximity: -0.9746
# Epoch 10/100
# 45/44 [==============================] - 29s 640ms/step - loss: 1.1996 - mean_squared_error: 1.1996 - mean_absolute_error: 0.8044 - mean_absolute_percentage_error: 1684013.3635 - cosine_proximity: -0.8886 - val_loss: 0.4992 - val_mean_squared_error: 0.4992 - val_mean_absolute_error: 0.5327 - val_mean_absolute_percentage_error: 1349295.9649 - val_cosine_proximity: -0.9859
# Epoch 11/100
# 45/44 [==============================] - 29s 645ms/step - loss: 1.0430 - mean_squared_error: 1.0430 - mean_absolute_error: 0.7522 - mean_absolute_percentage_error: 1491149.8707 - cosine_proximity: -0.9009 - val_loss: 0.3642 - val_mean_squared_error: 0.3642 - val_mean_absolute_error: 0.4641 - val_mean_absolute_percentage_error: 1329304.2784 - val_cosine_proximity: -0.9803
# Epoch 12/100
# 45/44 [==============================] - 31s 679ms/step - loss: 1.0183 - mean_squared_error: 1.0183 - mean_absolute_error: 0.7430 - mean_absolute_percentage_error: 2475261.5278 - cosine_proximity: -0.9120 - val_loss: 0.7551 - val_mean_squared_error: 0.7551 - val_mean_absolute_error: 0.6589 - val_mean_absolute_percentage_error: 1349142.2439 - val_cosine_proximity: -0.9803
# Epoch 13/100
# 45/44 [==============================] - 31s 683ms/step - loss: 1.0366 - mean_squared_error: 1.0366 - mean_absolute_error: 0.7401 - mean_absolute_percentage_error: 1814827.4936 - cosine_proximity: -0.8982 - val_loss: 0.2375 - val_mean_squared_error: 0.2375 - val_mean_absolute_error: 0.3854 - val_mean_absolute_percentage_error: 1050135.9470 - val_cosine_proximity: -0.9915
# Epoch 14/100
# 45/44 [==============================] - 43s 964ms/step - loss: 1.0617 - mean_squared_error: 1.0617 - mean_absolute_error: 0.7417 - mean_absolute_percentage_error: 2576182.8384 - cosine_proximity: -0.9107 - val_loss: 0.2806 - val_mean_squared_error: 0.2806 - val_mean_absolute_error: 0.4078 - val_mean_absolute_percentage_error: 1427915.2127 - val_cosine_proximity: -0.9915
# Epoch 15/100
# 45/44 [==============================] - 31s 679ms/step - loss: 0.9946 - mean_squared_error: 0.9946 - mean_absolute_error: 0.7321 - mean_absolute_percentage_error: 1804638.8938 - cosine_proximity: -0.8998 - val_loss: 0.3964 - val_mean_squared_error: 0.3964 - val_mean_absolute_error: 0.4783 - val_mean_absolute_percentage_error: 1266685.4040 - val_cosine_proximity: -0.9915
# Epoch 16/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.9815 - mean_squared_error: 0.9815 - mean_absolute_error: 0.7182 - mean_absolute_percentage_error: 1573375.1403 - cosine_proximity: -0.9259 - val_loss: 0.4545 - val_mean_squared_error: 0.4545 - val_mean_absolute_error: 0.5205 - val_mean_absolute_percentage_error: 1204892.1085 - val_cosine_proximity: -0.9859
# Epoch 17/100
# 45/44 [==============================] - 27s 599ms/step - loss: 1.0235 - mean_squared_error: 1.0235 - mean_absolute_error: 0.7335 - mean_absolute_percentage_error: 1775775.9354 - cosine_proximity: -0.9107 - val_loss: 0.3763 - val_mean_squared_error: 0.3763 - val_mean_absolute_error: 0.4658 - val_mean_absolute_percentage_error: 1273541.7733 - val_cosine_proximity: -0.9859
# Epoch 18/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.9282 - mean_squared_error: 0.9282 - mean_absolute_error: 0.7044 - mean_absolute_percentage_error: 2635635.7752 - cosine_proximity: -0.9273 - val_loss: 0.4008 - val_mean_squared_error: 0.4008 - val_mean_absolute_error: 0.4937 - val_mean_absolute_percentage_error: 1383676.6443 - val_cosine_proximity: -0.9859
# Epoch 19/100
# 45/44 [==============================] - 27s 599ms/step - loss: 0.9045 - mean_squared_error: 0.9045 - mean_absolute_error: 0.6950 - mean_absolute_percentage_error: 1456201.6846 - cosine_proximity: -0.9222 - val_loss: 0.4114 - val_mean_squared_error: 0.4114 - val_mean_absolute_error: 0.4939 - val_mean_absolute_percentage_error: 482869.4609 - val_cosine_proximity: -0.9803
# Epoch 20/100
# 45/44 [==============================] - 27s 598ms/step - loss: 0.8823 - mean_squared_error: 0.8823 - mean_absolute_error: 0.6776 - mean_absolute_percentage_error: 1250643.3742 - cosine_proximity: -0.9403 - val_loss: 0.5016 - val_mean_squared_error: 0.5016 - val_mean_absolute_error: 0.5423 - val_mean_absolute_percentage_error: 1237828.8664 - val_cosine_proximity: -0.9915
# Epoch 21/100
# 45/44 [==============================] - 27s 600ms/step - loss: 0.9033 - mean_squared_error: 0.9033 - mean_absolute_error: 0.6950 - mean_absolute_percentage_error: 1973553.4741 - cosine_proximity: -0.9248 - val_loss: 0.4868 - val_mean_squared_error: 0.4868 - val_mean_absolute_error: 0.5344 - val_mean_absolute_percentage_error: 1400926.9512 - val_cosine_proximity: -0.9915
# Epoch 22/100
# 45/44 [==============================] - 28s 621ms/step - loss: 0.9267 - mean_squared_error: 0.9267 - mean_absolute_error: 0.7065 - mean_absolute_percentage_error: 2671879.8063 - cosine_proximity: -0.9361 - val_loss: 0.2399 - val_mean_squared_error: 0.2399 - val_mean_absolute_error: 0.3787 - val_mean_absolute_percentage_error: 1452138.2111 - val_cosine_proximity: -0.9915
# Epoch 23/100
# 45/44 [==============================] - 28s 625ms/step - loss: 0.8983 - mean_squared_error: 0.8983 - mean_absolute_error: 0.6884 - mean_absolute_percentage_error: 1981758.3412 - cosine_proximity: -0.9174 - val_loss: 0.4662 - val_mean_squared_error: 0.4662 - val_mean_absolute_error: 0.5233 - val_mean_absolute_percentage_error: 1451846.1693 - val_cosine_proximity: -0.9859
# Epoch 24/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8844 - mean_squared_error: 0.8844 - mean_absolute_error: 0.6927 - mean_absolute_percentage_error: 1832384.6861 - cosine_proximity: -0.9359 - val_loss: 0.2670 - val_mean_squared_error: 0.2670 - val_mean_absolute_error: 0.3958 - val_mean_absolute_percentage_error: 1218333.8210 - val_cosine_proximity: -0.9803
# Epoch 25/100
# 45/44 [==============================] - 27s 600ms/step - loss: 0.9136 - mean_squared_error: 0.9136 - mean_absolute_error: 0.6999 - mean_absolute_percentage_error: 1963031.9381 - cosine_proximity: -0.9174 - val_loss: 0.4267 - val_mean_squared_error: 0.4267 - val_mean_absolute_error: 0.4972 - val_mean_absolute_percentage_error: 1237634.5842 - val_cosine_proximity: -0.9746
# Epoch 26/100
# 45/44 [==============================] - 28s 614ms/step - loss: 0.9058 - mean_squared_error: 0.9058 - mean_absolute_error: 0.6933 - mean_absolute_percentage_error: 2540297.6306 - cosine_proximity: -0.9190 - val_loss: 0.4174 - val_mean_squared_error: 0.4174 - val_mean_absolute_error: 0.4958 - val_mean_absolute_percentage_error: 1465577.9219 - val_cosine_proximity: -0.9972
# Epoch 27/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.9651 - mean_squared_error: 0.9651 - mean_absolute_error: 0.7143 - mean_absolute_percentage_error: 2464119.4900 - cosine_proximity: -0.9262 - val_loss: 0.2221 - val_mean_squared_error: 0.2221 - val_mean_absolute_error: 0.3701 - val_mean_absolute_percentage_error: 1612319.5819 - val_cosine_proximity: -0.9859
# Epoch 28/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.8587 - mean_squared_error: 0.8587 - mean_absolute_error: 0.6689 - mean_absolute_percentage_error: 1211048.7279 - cosine_proximity: -0.9190 - val_loss: 0.4107 - val_mean_squared_error: 0.4107 - val_mean_absolute_error: 0.4935 - val_mean_absolute_percentage_error: 1711855.5403 - val_cosine_proximity: -0.9634
# Epoch 29/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.8297 - mean_squared_error: 0.8297 - mean_absolute_error: 0.6657 - mean_absolute_percentage_error: 978057.1691 - cosine_proximity: -0.9345 - val_loss: 0.2319 - val_mean_squared_error: 0.2319 - val_mean_absolute_error: 0.3721 - val_mean_absolute_percentage_error: 922986.9779 - val_cosine_proximity: -0.9859
# Epoch 30/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.8969 - mean_squared_error: 0.8969 - mean_absolute_error: 0.6972 - mean_absolute_percentage_error: 1191988.5006 - cosine_proximity: -0.9289 - val_loss: 0.3732 - val_mean_squared_error: 0.3732 - val_mean_absolute_error: 0.4669 - val_mean_absolute_percentage_error: 1582449.3685 - val_cosine_proximity: -0.9859
# Epoch 31/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.9017 - mean_squared_error: 0.9017 - mean_absolute_error: 0.6887 - mean_absolute_percentage_error: 1557000.7077 - cosine_proximity: -0.9250 - val_loss: 0.2302 - val_mean_squared_error: 0.2302 - val_mean_absolute_error: 0.3790 - val_mean_absolute_percentage_error: 1327529.8404 - val_cosine_proximity: -0.9859
# Epoch 32/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.9236 - mean_squared_error: 0.9236 - mean_absolute_error: 0.6959 - mean_absolute_percentage_error: 1485048.8920 - cosine_proximity: -0.9091 - val_loss: 0.5623 - val_mean_squared_error: 0.5623 - val_mean_absolute_error: 0.5714 - val_mean_absolute_percentage_error: 1302119.2261 - val_cosine_proximity: -0.9859
# Epoch 33/100
# 45/44 [==============================] - 27s 604ms/step - loss: 0.8225 - mean_squared_error: 0.8225 - mean_absolute_error: 0.6549 - mean_absolute_percentage_error: 2449927.2091 - cosine_proximity: -0.9430 - val_loss: 0.3656 - val_mean_squared_error: 0.3656 - val_mean_absolute_error: 0.4559 - val_mean_absolute_percentage_error: 1861093.8647 - val_cosine_proximity: -0.9859
# Epoch 34/100
# 45/44 [==============================] - 27s 606ms/step - loss: 0.8580 - mean_squared_error: 0.8580 - mean_absolute_error: 0.6755 - mean_absolute_percentage_error: 2594221.7022 - cosine_proximity: -0.9287 - val_loss: 0.3786 - val_mean_squared_error: 0.3786 - val_mean_absolute_error: 0.4753 - val_mean_absolute_percentage_error: 1496569.9979 - val_cosine_proximity: -0.9859
# Epoch 35/100
# 45/44 [==============================] - 27s 600ms/step - loss: 0.8017 - mean_squared_error: 0.8017 - mean_absolute_error: 0.6579 - mean_absolute_percentage_error: 1450350.1005 - cosine_proximity: -0.9305 - val_loss: 0.3559 - val_mean_squared_error: 0.3559 - val_mean_absolute_error: 0.4554 - val_mean_absolute_percentage_error: 443601.8596 - val_cosine_proximity: -0.9803
# Epoch 36/100
# 45/44 [==============================] - 27s 599ms/step - loss: 0.8794 - mean_squared_error: 0.8794 - mean_absolute_error: 0.6836 - mean_absolute_percentage_error: 2265691.1833 - cosine_proximity: -0.8982 - val_loss: 0.3020 - val_mean_squared_error: 0.3020 - val_mean_absolute_error: 0.4211 - val_mean_absolute_percentage_error: 1443265.4668 - val_cosine_proximity: -0.9746
# Epoch 37/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8832 - mean_squared_error: 0.8832 - mean_absolute_error: 0.6850 - mean_absolute_percentage_error: 2416873.2886 - cosine_proximity: -0.9291 - val_loss: 1.5178 - val_mean_squared_error: 1.5178 - val_mean_absolute_error: 0.8581 - val_mean_absolute_percentage_error: 1885368.2454 - val_cosine_proximity: -0.7211
# Epoch 38/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.9029 - mean_squared_error: 0.9029 - mean_absolute_error: 0.7042 - mean_absolute_percentage_error: 2638893.5763 - cosine_proximity: -0.9039 - val_loss: 0.2214 - val_mean_squared_error: 0.2214 - val_mean_absolute_error: 0.3570 - val_mean_absolute_percentage_error: 1457382.3810 - val_cosine_proximity: -0.9915
# Epoch 39/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8949 - mean_squared_error: 0.8949 - mean_absolute_error: 0.6890 - mean_absolute_percentage_error: 2286673.2061 - cosine_proximity: -0.9275 - val_loss: 0.3166 - val_mean_squared_error: 0.3166 - val_mean_absolute_error: 0.4283 - val_mean_absolute_percentage_error: 1646388.6587 - val_cosine_proximity: -0.9972
# Epoch 40/100
# 45/44 [==============================] - 27s 599ms/step - loss: 0.8786 - mean_squared_error: 0.8786 - mean_absolute_error: 0.6678 - mean_absolute_percentage_error: 2568650.7078 - cosine_proximity: -0.9456 - val_loss: 0.3675 - val_mean_squared_error: 0.3675 - val_mean_absolute_error: 0.4609 - val_mean_absolute_percentage_error: 1813321.5313 - val_cosine_proximity: -0.9915
# Epoch 41/100
# 45/44 [==============================] - 27s 599ms/step - loss: 0.8491 - mean_squared_error: 0.8491 - mean_absolute_error: 0.6717 - mean_absolute_percentage_error: 2471582.0513 - cosine_proximity: -0.9289 - val_loss: 0.3755 - val_mean_squared_error: 0.3755 - val_mean_absolute_error: 0.4667 - val_mean_absolute_percentage_error: 2078460.9117 - val_cosine_proximity: -0.9915
# Epoch 42/100
# 45/44 [==============================] - 27s 611ms/step - loss: 0.8495 - mean_squared_error: 0.8495 - mean_absolute_error: 0.6649 - mean_absolute_percentage_error: 1840335.9032 - cosine_proximity: -0.9371 - val_loss: 0.4726 - val_mean_squared_error: 0.4726 - val_mean_absolute_error: 0.5270 - val_mean_absolute_percentage_error: 1853896.5841 - val_cosine_proximity: -0.9859
# Epoch 43/100
# 45/44 [==============================] - 28s 616ms/step - loss: 0.8695 - mean_squared_error: 0.8695 - mean_absolute_error: 0.6812 - mean_absolute_percentage_error: 3392578.4324 - cosine_proximity: -0.9361 - val_loss: 0.3823 - val_mean_squared_error: 0.3823 - val_mean_absolute_error: 0.4711 - val_mean_absolute_percentage_error: 1935936.2334 - val_cosine_proximity: -0.9915
# Epoch 44/100
# 45/44 [==============================] - 28s 619ms/step - loss: 0.8587 - mean_squared_error: 0.8587 - mean_absolute_error: 0.6723 - mean_absolute_percentage_error: 2121849.7929 - cosine_proximity: -0.9176 - val_loss: 0.3921 - val_mean_squared_error: 0.3921 - val_mean_absolute_error: 0.4757 - val_mean_absolute_percentage_error: 1758265.0720 - val_cosine_proximity: -0.9915
# Epoch 45/100
# 45/44 [==============================] - 27s 606ms/step - loss: 0.7986 - mean_squared_error: 0.7986 - mean_absolute_error: 0.6459 - mean_absolute_percentage_error: 1633568.5879 - cosine_proximity: -0.9343 - val_loss: 0.2807 - val_mean_squared_error: 0.2807 - val_mean_absolute_error: 0.4110 - val_mean_absolute_percentage_error: 2317668.4156 - val_cosine_proximity: -0.9915
# Epoch 46/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.7619 - mean_squared_error: 0.7619 - mean_absolute_error: 0.6306 - mean_absolute_percentage_error: 2858847.6507 - cosine_proximity: -0.9345 - val_loss: 0.3772 - val_mean_squared_error: 0.3772 - val_mean_absolute_error: 0.4758 - val_mean_absolute_percentage_error: 1639342.9208 - val_cosine_proximity: -0.9915
# Epoch 47/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.8424 - mean_squared_error: 0.8424 - mean_absolute_error: 0.6763 - mean_absolute_percentage_error: 1500745.0801 - cosine_proximity: -0.9442 - val_loss: 0.2699 - val_mean_squared_error: 0.2699 - val_mean_absolute_error: 0.4017 - val_mean_absolute_percentage_error: 1617615.3847 - val_cosine_proximity: -0.9915
# Epoch 48/100
# 45/44 [==============================] - 27s 600ms/step - loss: 0.8126 - mean_squared_error: 0.8126 - mean_absolute_error: 0.6522 - mean_absolute_percentage_error: 2076147.4010 - cosine_proximity: -0.9428 - val_loss: 0.2434 - val_mean_squared_error: 0.2434 - val_mean_absolute_error: 0.3777 - val_mean_absolute_percentage_error: 1798246.6004 - val_cosine_proximity: -0.9803
# Epoch 49/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8975 - mean_squared_error: 0.8975 - mean_absolute_error: 0.6831 - mean_absolute_percentage_error: 1370146.1439 - cosine_proximity: -0.9343 - val_loss: 0.3677 - val_mean_squared_error: 0.3677 - val_mean_absolute_error: 0.4697 - val_mean_absolute_percentage_error: 1599803.3121 - val_cosine_proximity: -0.9859
# Epoch 50/100
# 45/44 [==============================] - 27s 604ms/step - loss: 0.7832 - mean_squared_error: 0.7832 - mean_absolute_error: 0.6364 - mean_absolute_percentage_error: 919948.2008 - cosine_proximity: -0.9412 - val_loss: 0.3454 - val_mean_squared_error: 0.3454 - val_mean_absolute_error: 0.4425 - val_mean_absolute_percentage_error: 1515872.3054 - val_cosine_proximity: -0.9972
# Epoch 51/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - mean_absolute_error: 0.6181 - mean_absolute_percentage_error: 2613591.1819 - cosine_proximity: -0.9426 - val_loss: 0.3967 - val_mean_squared_error: 0.3967 - val_mean_absolute_error: 0.4780 - val_mean_absolute_percentage_error: 1867876.2378 - val_cosine_proximity: -0.9859
# Epoch 52/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.7696 - mean_squared_error: 0.7696 - mean_absolute_error: 0.6399 - mean_absolute_percentage_error: 1490121.0840 - cosine_proximity: -0.9289 - val_loss: 0.3454 - val_mean_squared_error: 0.3454 - val_mean_absolute_error: 0.4554 - val_mean_absolute_percentage_error: 1542547.1528 - val_cosine_proximity: -0.9859
# Epoch 53/100
# 45/44 [==============================] - 27s 605ms/step - loss: 0.7667 - mean_squared_error: 0.7667 - mean_absolute_error: 0.6354 - mean_absolute_percentage_error: 1522826.3968 - cosine_proximity: -0.9539 - val_loss: 0.3384 - val_mean_squared_error: 0.3384 - val_mean_absolute_error: 0.4541 - val_mean_absolute_percentage_error: 1500030.3242 - val_cosine_proximity: -0.9915
# Epoch 54/100
# 45/44 [==============================] - 27s 606ms/step - loss: 0.7703 - mean_squared_error: 0.7703 - mean_absolute_error: 0.6335 - mean_absolute_percentage_error: 902285.8187 - cosine_proximity: -0.9428 - val_loss: 0.2714 - val_mean_squared_error: 0.2714 - val_mean_absolute_error: 0.4072 - val_mean_absolute_percentage_error: 1545690.3694 - val_cosine_proximity: -0.9915
# Epoch 55/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7950 - mean_squared_error: 0.7950 - mean_absolute_error: 0.6377 - mean_absolute_percentage_error: 1867240.8192 - cosine_proximity: -0.9470 - val_loss: 0.2865 - val_mean_squared_error: 0.2865 - val_mean_absolute_error: 0.4138 - val_mean_absolute_percentage_error: 853945.1861 - val_cosine_proximity: -0.9859
# Epoch 56/100
# 45/44 [==============================] - 27s 607ms/step - loss: 0.8407 - mean_squared_error: 0.8407 - mean_absolute_error: 0.6622 - mean_absolute_percentage_error: 1917973.3235 - cosine_proximity: -0.9428 - val_loss: 0.3863 - val_mean_squared_error: 0.3863 - val_mean_absolute_error: 0.4730 - val_mean_absolute_percentage_error: 1136023.5125 - val_cosine_proximity: -0.9915
# Epoch 57/100
# 45/44 [==============================] - 27s 606ms/step - loss: 0.8413 - mean_squared_error: 0.8413 - mean_absolute_error: 0.6609 - mean_absolute_percentage_error: 2374955.0985 - cosine_proximity: -0.9440 - val_loss: 0.2528 - val_mean_squared_error: 0.2528 - val_mean_absolute_error: 0.3939 - val_mean_absolute_percentage_error: 1196350.8221 - val_cosine_proximity: -0.9972
# Epoch 58/100
# 45/44 [==============================] - 27s 604ms/step - loss: 0.7995 - mean_squared_error: 0.7995 - mean_absolute_error: 0.6470 - mean_absolute_percentage_error: 1515330.6497 - cosine_proximity: -0.9526 - val_loss: 0.3394 - val_mean_squared_error: 0.3394 - val_mean_absolute_error: 0.4502 - val_mean_absolute_percentage_error: 473498.7998 - val_cosine_proximity: -0.9972
# Epoch 59/100
# 45/44 [==============================] - 27s 604ms/step - loss: 0.7931 - mean_squared_error: 0.7931 - mean_absolute_error: 0.6495 - mean_absolute_percentage_error: 1784039.5035 - cosine_proximity: -0.9597 - val_loss: 0.3105 - val_mean_squared_error: 0.3105 - val_mean_absolute_error: 0.4295 - val_mean_absolute_percentage_error: 224295.2056 - val_cosine_proximity: -0.9915
# Epoch 60/100
# 45/44 [==============================] - 27s 603ms/step - loss: 0.7934 - mean_squared_error: 0.7934 - mean_absolute_error: 0.6417 - mean_absolute_percentage_error: 2445323.1692 - cosine_proximity: -0.9327 - val_loss: 0.3030 - val_mean_squared_error: 0.3030 - val_mean_absolute_error: 0.4224 - val_mean_absolute_percentage_error: 1221487.8041 - val_cosine_proximity: -0.9972
# Epoch 61/100
# 45/44 [==============================] - 27s 600ms/step - loss: 0.7632 - mean_squared_error: 0.7632 - mean_absolute_error: 0.6420 - mean_absolute_percentage_error: 2037520.3229 - cosine_proximity: -0.9553 - val_loss: 0.3766 - val_mean_squared_error: 0.3766 - val_mean_absolute_error: 0.4677 - val_mean_absolute_percentage_error: 1672507.3318 - val_cosine_proximity: -0.9915
# Epoch 62/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8100 - mean_squared_error: 0.8100 - mean_absolute_error: 0.6506 - mean_absolute_percentage_error: 1667711.8090 - cosine_proximity: -0.9593 - val_loss: 0.3125 - val_mean_squared_error: 0.3125 - val_mean_absolute_error: 0.4344 - val_mean_absolute_percentage_error: 1608813.0161 - val_cosine_proximity: -0.9972
# Epoch 63/100
# 45/44 [==============================] - 27s 602ms/step - loss: 0.7998 - mean_squared_error: 0.7998 - mean_absolute_error: 0.6463 - mean_absolute_percentage_error: 1282600.8032 - cosine_proximity: -0.9456 - val_loss: 0.2610 - val_mean_squared_error: 0.2610 - val_mean_absolute_error: 0.3974 - val_mean_absolute_percentage_error: 1508647.9963 - val_cosine_proximity: -0.9972
# Epoch 64/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.7964 - mean_squared_error: 0.7964 - mean_absolute_error: 0.6557 - mean_absolute_percentage_error: 1958067.4217 - cosine_proximity: -0.9394 - val_loss: 0.3562 - val_mean_squared_error: 0.3562 - val_mean_absolute_error: 0.4535 - val_mean_absolute_percentage_error: 1330290.8237 - val_cosine_proximity: -0.9859
# Epoch 65/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.7692 - mean_squared_error: 0.7692 - mean_absolute_error: 0.6379 - mean_absolute_percentage_error: 2755857.5204 - cosine_proximity: -0.9553 - val_loss: 0.4071 - val_mean_squared_error: 0.4071 - val_mean_absolute_error: 0.4863 - val_mean_absolute_percentage_error: 1265996.0212 - val_cosine_proximity: -0.9915
# Epoch 66/100
# 45/44 [==============================] - 27s 601ms/step - loss: 0.8052 - mean_squared_error: 0.8052 - mean_absolute_error: 0.6429 - mean_absolute_percentage_error: 1767436.5073 - cosine_proximity: -0.9555 - val_loss: 0.2939 - val_mean_squared_error: 0.2939 - val_mean_absolute_error: 0.4140 - val_mean_absolute_percentage_error: 1133816.7827 - val_cosine_proximity: -0.9915
# Epoch 67/100
# 45/44 [==============================] - 27s 606ms/step - loss: 0.7700 - mean_squared_error: 0.7700 - mean_absolute_error: 0.6307 - mean_absolute_percentage_error: 1575479.1283 - cosine_proximity: -0.9625 - val_loss: 0.3717 - val_mean_squared_error: 0.3717 - val_mean_absolute_error: 0.4633 - val_mean_absolute_percentage_error: 1026593.7142 - val_cosine_proximity: -0.9915
# Epoch 68/100
# 45/44 [==============================] - 28s 621ms/step - loss: 0.8062 - mean_squared_error: 0.8062 - mean_absolute_error: 0.6488 - mean_absolute_percentage_error: 1616830.4032 - cosine_proximity: -0.9470 - val_loss: 0.4180 - val_mean_squared_error: 0.4180 - val_mean_absolute_error: 0.4840 - val_mean_absolute_percentage_error: 1519540.9052 - val_cosine_proximity: -0.9859
# Epoch 69/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7746 - mean_squared_error: 0.7746 - mean_absolute_error: 0.6414 - mean_absolute_percentage_error: 1428978.2814 - cosine_proximity: -0.9428 - val_loss: 0.3060 - val_mean_squared_error: 0.3060 - val_mean_absolute_error: 0.4323 - val_mean_absolute_percentage_error: 1439957.4732 - val_cosine_proximity: -0.9972
# Epoch 70/100
# 45/44 [==============================] - 28s 615ms/step - loss: 0.7177 - mean_squared_error: 0.7177 - mean_absolute_error: 0.6137 - mean_absolute_percentage_error: 1521136.4360 - cosine_proximity: -0.9329 - val_loss: 0.4203 - val_mean_squared_error: 0.4203 - val_mean_absolute_error: 0.4891 - val_mean_absolute_percentage_error: 1410471.7036 - val_cosine_proximity: -0.9972
# Epoch 71/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.8175 - mean_squared_error: 0.8175 - mean_absolute_error: 0.6542 - mean_absolute_percentage_error: 1418269.6073 - cosine_proximity: -0.9625 - val_loss: 0.3122 - val_mean_squared_error: 0.3122 - val_mean_absolute_error: 0.4258 - val_mean_absolute_percentage_error: 1572764.2910 - val_cosine_proximity: -0.9915
# Epoch 72/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7655 - mean_squared_error: 0.7655 - mean_absolute_error: 0.6385 - mean_absolute_percentage_error: 2251683.2638 - cosine_proximity: -0.9428 - val_loss: 0.3147 - val_mean_squared_error: 0.3147 - val_mean_absolute_error: 0.4304 - val_mean_absolute_percentage_error: 1583507.0087 - val_cosine_proximity: -0.9972
# Epoch 73/100
# 45/44 [==============================] - 28s 614ms/step - loss: 0.8385 - mean_squared_error: 0.8385 - mean_absolute_error: 0.6650 - mean_absolute_percentage_error: 2098812.8794 - cosine_proximity: -0.9398 - val_loss: 0.3866 - val_mean_squared_error: 0.3866 - val_mean_absolute_error: 0.4771 - val_mean_absolute_percentage_error: 1487663.5196 - val_cosine_proximity: -0.9915
# Epoch 74/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7810 - mean_squared_error: 0.7810 - mean_absolute_error: 0.6526 - mean_absolute_percentage_error: 2526549.2831 - cosine_proximity: -0.9484 - val_loss: 0.3414 - val_mean_squared_error: 0.3414 - val_mean_absolute_error: 0.4464 - val_mean_absolute_percentage_error: 1574050.8021 - val_cosine_proximity: -0.9972
# Epoch 75/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7410 - mean_squared_error: 0.7410 - mean_absolute_error: 0.6227 - mean_absolute_percentage_error: 1701079.3737 - cosine_proximity: -0.9667 - val_loss: 0.3995 - val_mean_squared_error: 0.3995 - val_mean_absolute_error: 0.4865 - val_mean_absolute_percentage_error: 1445685.2390 - val_cosine_proximity: -0.9915
# Epoch 76/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7631 - mean_squared_error: 0.7631 - mean_absolute_error: 0.6334 - mean_absolute_percentage_error: 2817676.9647 - cosine_proximity: -0.9583 - val_loss: 0.4146 - val_mean_squared_error: 0.4146 - val_mean_absolute_error: 0.4874 - val_mean_absolute_percentage_error: 1442789.5069 - val_cosine_proximity: -0.9915
# Epoch 77/100
# 45/44 [==============================] - 28s 620ms/step - loss: 0.7858 - mean_squared_error: 0.7858 - mean_absolute_error: 0.6388 - mean_absolute_percentage_error: 1462935.1670 - cosine_proximity: -0.9542 - val_loss: 0.3468 - val_mean_squared_error: 0.3468 - val_mean_absolute_error: 0.4544 - val_mean_absolute_percentage_error: 896823.2838 - val_cosine_proximity: -0.9972
# Epoch 78/100
# 45/44 [==============================] - 28s 614ms/step - loss: 0.8072 - mean_squared_error: 0.8072 - mean_absolute_error: 0.6562 - mean_absolute_percentage_error: 2194303.1995 - cosine_proximity: -0.9414 - val_loss: 0.2776 - val_mean_squared_error: 0.2776 - val_mean_absolute_error: 0.4051 - val_mean_absolute_percentage_error: 1531760.5012 - val_cosine_proximity: -0.9972
# Epoch 79/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7813 - mean_squared_error: 0.7813 - mean_absolute_error: 0.6329 - mean_absolute_percentage_error: 1512598.6617 - cosine_proximity: -0.9651 - val_loss: 0.3705 - val_mean_squared_error: 0.3705 - val_mean_absolute_error: 0.4543 - val_mean_absolute_percentage_error: 1648802.4927 - val_cosine_proximity: -0.9859
# Epoch 80/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.8324 - mean_squared_error: 0.8324 - mean_absolute_error: 0.6600 - mean_absolute_percentage_error: 1473575.9972 - cosine_proximity: -0.9400 - val_loss: 0.4074 - val_mean_squared_error: 0.4074 - val_mean_absolute_error: 0.4781 - val_mean_absolute_percentage_error: 1456024.3871 - val_cosine_proximity: -0.9859
# Epoch 81/100
# 45/44 [==============================] - 28s 615ms/step - loss: 0.7778 - mean_squared_error: 0.7778 - mean_absolute_error: 0.6325 - mean_absolute_percentage_error: 2047020.5656 - cosine_proximity: -0.9512 - val_loss: 0.4149 - val_mean_squared_error: 0.4149 - val_mean_absolute_error: 0.4900 - val_mean_absolute_percentage_error: 1686025.9665 - val_cosine_proximity: -0.9803
# Epoch 82/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.8468 - mean_squared_error: 0.8468 - mean_absolute_error: 0.6733 - mean_absolute_percentage_error: 2303529.0886 - cosine_proximity: -0.9345 - val_loss: 0.4071 - val_mean_squared_error: 0.4071 - val_mean_absolute_error: 0.4834 - val_mean_absolute_percentage_error: 1530088.8799 - val_cosine_proximity: -0.9915
# Epoch 83/100
# 45/44 [==============================] - 27s 611ms/step - loss: 0.7872 - mean_squared_error: 0.7872 - mean_absolute_error: 0.6388 - mean_absolute_percentage_error: 2317736.8636 - cosine_proximity: -0.9583 - val_loss: 0.2675 - val_mean_squared_error: 0.2675 - val_mean_absolute_error: 0.4067 - val_mean_absolute_percentage_error: 892206.5042 - val_cosine_proximity: -0.9972
# Epoch 84/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.7628 - mean_squared_error: 0.7628 - mean_absolute_error: 0.6257 - mean_absolute_percentage_error: 1031867.2612 - cosine_proximity: -0.9470 - val_loss: 0.4100 - val_mean_squared_error: 0.4100 - val_mean_absolute_error: 0.4883 - val_mean_absolute_percentage_error: 1263152.6211 - val_cosine_proximity: -0.9972
# Epoch 85/100
# 45/44 [==============================] - 27s 610ms/step - loss: 0.7489 - mean_squared_error: 0.7489 - mean_absolute_error: 0.6328 - mean_absolute_percentage_error: 1958170.4237 - cosine_proximity: -0.9581 - val_loss: 0.3982 - val_mean_squared_error: 0.3982 - val_mean_absolute_error: 0.4829 - val_mean_absolute_percentage_error: 1651596.2871 - val_cosine_proximity: -0.9915
# Epoch 86/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.7688 - mean_squared_error: 0.7688 - mean_absolute_error: 0.6353 - mean_absolute_percentage_error: 1729067.8916 - cosine_proximity: -0.9555 - val_loss: 0.2697 - val_mean_squared_error: 0.2697 - val_mean_absolute_error: 0.4047 - val_mean_absolute_percentage_error: 1531358.6228 - val_cosine_proximity: -0.9972
# Epoch 87/100
# 45/44 [==============================] - 27s 610ms/step - loss: 0.7693 - mean_squared_error: 0.7693 - mean_absolute_error: 0.6304 - mean_absolute_percentage_error: 1032312.8787 - cosine_proximity: -0.9512 - val_loss: 0.4418 - val_mean_squared_error: 0.4418 - val_mean_absolute_error: 0.5010 - val_mean_absolute_percentage_error: 1440668.9511 - val_cosine_proximity: -0.9972
# Epoch 88/100
# 45/44 [==============================] - 28s 615ms/step - loss: 0.7657 - mean_squared_error: 0.7657 - mean_absolute_error: 0.6317 - mean_absolute_percentage_error: 1907721.1280 - cosine_proximity: -0.9375 - val_loss: 0.3910 - val_mean_squared_error: 0.3910 - val_mean_absolute_error: 0.4816 - val_mean_absolute_percentage_error: 1747174.4892 - val_cosine_proximity: -0.9972
# Epoch 89/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.7450 - mean_squared_error: 0.7450 - mean_absolute_error: 0.6337 - mean_absolute_percentage_error: 1453176.4805 - cosine_proximity: -0.9317 - val_loss: 0.3141 - val_mean_squared_error: 0.3141 - val_mean_absolute_error: 0.4366 - val_mean_absolute_percentage_error: 1582848.6498 - val_cosine_proximity: -0.9972
# Epoch 90/100
# 45/44 [==============================] - 28s 614ms/step - loss: 0.7105 - mean_squared_error: 0.7105 - mean_absolute_error: 0.6208 - mean_absolute_percentage_error: 1697378.2148 - cosine_proximity: -0.9319 - val_loss: 0.3063 - val_mean_squared_error: 0.3063 - val_mean_absolute_error: 0.4231 - val_mean_absolute_percentage_error: 2189007.6448 - val_cosine_proximity: -0.9972
# Epoch 91/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.8027 - mean_squared_error: 0.8027 - mean_absolute_error: 0.6445 - mean_absolute_percentage_error: 2242658.6898 - cosine_proximity: -0.9542 - val_loss: 0.2598 - val_mean_squared_error: 0.2598 - val_mean_absolute_error: 0.3961 - val_mean_absolute_percentage_error: 1360135.9983 - val_cosine_proximity: -0.9972
# Epoch 92/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - mean_absolute_error: 0.6172 - mean_absolute_percentage_error: 2228486.4712 - cosine_proximity: -0.9468 - val_loss: 0.2421 - val_mean_squared_error: 0.2421 - val_mean_absolute_error: 0.3824 - val_mean_absolute_percentage_error: 1327843.5481 - val_cosine_proximity: -0.9972
# Epoch 93/100
# 45/44 [==============================] - 27s 610ms/step - loss: 0.7688 - mean_squared_error: 0.7688 - mean_absolute_error: 0.6258 - mean_absolute_percentage_error: 1529352.7281 - cosine_proximity: -0.9482 - val_loss: 0.2257 - val_mean_squared_error: 0.2257 - val_mean_absolute_error: 0.3635 - val_mean_absolute_percentage_error: 1725132.8733 - val_cosine_proximity: -0.9915
# Epoch 94/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.7609 - mean_squared_error: 0.7609 - mean_absolute_error: 0.6240 - mean_absolute_percentage_error: 1890667.6267 - cosine_proximity: -0.9553 - val_loss: 0.2630 - val_mean_squared_error: 0.2630 - val_mean_absolute_error: 0.3961 - val_mean_absolute_percentage_error: 1433150.0711 - val_cosine_proximity: -0.9972
# Epoch 95/100
# 45/44 [==============================] - 28s 614ms/step - loss: 0.7352 - mean_squared_error: 0.7352 - mean_absolute_error: 0.6258 - mean_absolute_percentage_error: 1345527.1564 - cosine_proximity: -0.9539 - val_loss: 0.3624 - val_mean_squared_error: 0.3624 - val_mean_absolute_error: 0.4603 - val_mean_absolute_percentage_error: 1675544.7764 - val_cosine_proximity: -0.9972
# Epoch 96/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7545 - mean_squared_error: 0.7545 - mean_absolute_error: 0.6276 - mean_absolute_percentage_error: 1597355.4662 - cosine_proximity: -0.9625 - val_loss: 0.3139 - val_mean_squared_error: 0.3139 - val_mean_absolute_error: 0.4281 - val_mean_absolute_percentage_error: 143057.7588 - val_cosine_proximity: -0.9972
# Epoch 97/100
# 45/44 [==============================] - 28s 612ms/step - loss: 0.7329 - mean_squared_error: 0.7329 - mean_absolute_error: 0.6151 - mean_absolute_percentage_error: 1782799.1226 - cosine_proximity: -0.9454 - val_loss: 0.3464 - val_mean_squared_error: 0.3464 - val_mean_absolute_error: 0.4470 - val_mean_absolute_percentage_error: 1445301.4942 - val_cosine_proximity: -0.9972
# Epoch 98/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.6967 - mean_squared_error: 0.6967 - mean_absolute_error: 0.6122 - mean_absolute_percentage_error: 1721425.3889 - cosine_proximity: -0.9482 - val_loss: 0.3647 - val_mean_squared_error: 0.3647 - val_mean_absolute_error: 0.4640 - val_mean_absolute_percentage_error: 495946.5959 - val_cosine_proximity: -0.9972
# Epoch 99/100
# 45/44 [==============================] - 28s 613ms/step - loss: 0.7964 - mean_squared_error: 0.7964 - mean_absolute_error: 0.6538 - mean_absolute_percentage_error: 2231040.8749 - cosine_proximity: -0.9523 - val_loss: 0.3142 - val_mean_squared_error: 0.3142 - val_mean_absolute_error: 0.4326 - val_mean_absolute_percentage_error: 321926.0698 - val_cosine_proximity: -0.9972
# Epoch 100/100
# 45/44 [==============================] - 28s 618ms/step - loss: 0.8178 - mean_squared_error: 0.8178 - mean_absolute_error: 0.6562 - mean_absolute_percentage_error: 1495346.8008 - cosine_proximity: -0.9400 - val_loss: 0.4316 - val_mean_squared_error: 0.4316 - val_mean_absolute_error: 0.4992 - val_mean_absolute_percentage_error: 986330.9488 - val_cosine_proximity: -0.9972

# %% [markdown]
#  ## Save the Model

# %%
# Save model
model_path_full = model_path + '/'

model.save(model_path_full + 'RC_gt_2.h5')
with open(model_path_full + 'RC_gt_2.json', 'w') as output_json:
    output_json.write(model.to_json())

# %% [markdown]
# # Evaluate the Model

# %% [markdown]
# ## Plot the Training Results

# %%
# Plot the training and validation loss for each epoch
print('Generating loss chart...')
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.savefig(model_path_full + 'RC_gt_2_loss.png')

# Done
print('Done.')
# Out:
# Generating loss chart...
# Done.

# %% [markdown]
# ## Print Performance Metrics

# %%
scores = model.evaluate_generator(validation_generator, STEP_SIZE_VALID, use_multiprocessing=False)

metrics_names = model.metrics_names

for i in range(len(model.metrics_names)):
  print(("Metric: {} - {}").format(metrics_names[i],scores[i]))
# Out:
# Metric: loss - 0.431604150063555
# Metric: mean_squared_error - 0.431604150063555
# Metric: mean_absolute_error - 0.4992387232646136
# Metric: mean_absolute_percentage_error - 986330.9487648978
# Metric: cosine_proximity - -0.9971830985915493

# %% [markdown]
# ## Compute Prediction Statistics

# %%
# Define image loading function
def load_images(dataframe):
  
  # initialize images array
  images = []
  
  for i in dataframe.index.values:
    name = data_set + '/' + dataframe.loc[i,'filename']
    center_image = cv2.imread(name)
    center_image = cv2.resize(center_image, (320,180))
    images.append(center_image)
    
  return np.array(images)
  
# Load images 
test_size = 200
df_test = df.sample(frac=1).reset_index(drop=True)
df_test = df_test.head(test_size)

test_images = load_images(df_test)

batch_size = 32
preds = model.predict(test_images, batch_size=batch_size, verbose=1)

#print("Preds: {} \n".format(preds))

testY = df_test.iloc[:,4].values

#print("Labels: {} \n".format(testY))

df_testY = pd.Series(testY)
df_preds = pd.Series(preds.flatten)

# Replace 0 angle values
if df_testY.eq(0).any():
  df_testY.replace(0, 0.0001,inplace=True)

# Calculate the difference
diff = preds.flatten() - df_testY
percentDiff = (diff / testY) * 100
absPercentDiff = np.abs(percentDiff)

# compute the mean and standard deviation of the absolute percentage
# difference
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
print("[INFO] mean: {:.2f}%, std: {:.2f}%".format(mean, std))

# Compute the mean and standard deviation of the difference
print(diff.describe())

# Plot a histogram of the prediction errors
num_bins = 25
hist, bins = np.histogram(diff, num_bins)
center = (bins[:-1]+ bins[1:]) * 0.5
plt.bar(center, hist, width=0.05)
plt.title('Historgram of Predicted Error')
plt.xlabel('Steering Angle')
plt.ylabel('Number of predictions')
plt.xlim(-2.0, 2.0)
plt.plot(np.min(diff), np.max(diff))
# Out:
# 200/200 [==============================] - 1s 3ms/step
# [INFO] mean: 370.28%, std: 4614.37%
# count    200.000000
# mean      -0.072739
# std        0.666047
# min       -2.236854
# 25%       -0.446679
# 50%       -0.129470
# 75%        0.335222
# max        1.595308
# dtype: float64

# %%
# Plot a Scatter Plot of the Error
plt.scatter(testY, preds)
plt.xlabel('True Values ')
plt.ylabel('Predictions ')
plt.axis('equal')
plt.axis('square')
plt.xlim([-3.75,3.75])
plt.ylim([-3.75,3.75])
plt.plot([-3.75, 3.75], [-3.75, 3.75], color='k', linestyle='-', linewidth=.1)
plt.savefig(model_path_full + 'RC_gt_2_prediction.png')

# %% [markdown]
# ## Plot a Prediction

# %%
# Plot the image with the actual and predicted steering angle
index = random.randint(0,df_test.shape[0]-1)
img_name = data_set + '/' + df_test.loc[index,'filename']
center_image = cv2.imread(img_name)
center_image = cv2.cvtColor(center_image,cv2.COLOR_RGB2BGR)
center_image_mod = cv2.resize(center_image, (320,180)) #resize from 720x1280 to 180x320
plt.imshow(center_image_mod)
plt.grid(False)
plt.xlabel('Actual: {:.8f} Predicted: {:.8f}'.format(df_test.loc[index,'angle'],float(preds[index])))
plt.show()

# %% [markdown]
# #Visualize the Network
# https://www.analyticsvidhya.com/blog/2019/05/understanding-visualizing-neural-networks/

# %% [markdown]
# ##Show the Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cropping2d_1 (Cropping2D)    (None, 105, 320, 3)       0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 105, 320, 3)       0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 51, 158, 24)       1824
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 24, 77, 36)        21636
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 10, 37, 48)        43248
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 10, 37, 48)        0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 8, 35, 64)         27712
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 6, 33, 64)         36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12672)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1164)              14751372
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1164)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               116500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 15,004,791
# Trainable params: 15,004,791
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Access Individual Layers

# %%
# Creating a mapping of layer name ot layer details 
# We will create a dictionary layers_info which maps a layer name to its charcteristics
layers_info = {}
for i in model.layers:
    layers_info[i.name] = i.get_config()

#here the layer_weights dictionary will map every layer_name to its corresponding weights
layer_weights = {}
for i in model.layers:
    layer_weights[i.name] = i.get_weights()

pprint.pprint(layers_info['conv_5'])
# Out:
# {'activation': 'relu',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'VarianceScaling',
#                         'config': {'distribution': 'uniform',
#                                    'mode': 'fan_avg',
#                                    'scale': 1.0,
#                                    'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv_5',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}

# %% [markdown]
# ##Visualize the filters

# %%
# Visualize the first filter of each convolution layer
layers = model.layers
layer_ids = [2,3,4,6,7]

#plot the filters
fig,ax = plt.subplots(nrows=1,ncols=5)
for i in range(5):
    ax[i].imshow(layers[layer_ids[i]].get_weights()[0][:,:,:,0][:,:,0],cmap='gray')
    ax[i].set_title('Conv'+str(i+1))
    ax[i].set_xticks([])
    ax[i].set_yticks([])

# %% [markdown]
# ##Visualize the Saliency Map
#
# https://colab.research.google.com/github/idealo/cnn-exposed/blob/master/notebooks/Attribution.ipynb#scrollTo=jqSOW0pQniCw
#
# https://www.analyticsvidhya.com/blog/2019/05/understanding-visualizing-neural-networks/
#
# https://github.com/raghakot/keras-vis/blob/master/applications/self_driving/visualize_attention.ipynb

# %%
# !pip install -I scipy==1.2
#pip install git+https://github.com/raghakot/keras-vis.git -U

#import specific functions from keras-vis package
from vis.utils import utils
from vis.visualization import visualize_saliency, visualize_cam, overlay
# from keras.models import load_model
# import keras
# import random
# import pandas as pd
# import cv2
# #import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import tensorflow as tf

# # Assume that you have 12GB of GPU memory and want to allocate ~4GB:
# gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)

# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# print('############## Allowing Growth ###########')
# session = tf.Session(config=config)

# # -------------------  start importing keras module ---------------------
# import keras.backend.tensorflow_backend as K
# from keras.backend.tensorflow_backend import set_session
# set_session(tf.Session(config=config))

# %%
load = True #@param {type:"boolean"}

if load:
  # Returns a compiled model identical to the previous one
  #!curl -O https://selbystorage.s3-us-west-2.amazonaws.com/research/office_2/model.h5
  #!mv model.h5 model/
  #model_path_full = model_path + '/' + 'model.h5'
 
  model_path_full = 'C:/Users/master/Desktop/study/label_data/RC/model/RC_gt_2.h5'
  model = load_model(model_path_full)
  

  print("Loaded previous model: {} \n".format(model_path_full))
else:
  print("No previous model loaded \n")
# Out:
# Loaded previous model: C:/Users/master/Desktop/study/label_data/RC/model/RC_gt_100.h5

# %%
# View a Single Image 
#data_set = 'C:/Users/user/Desktop/Colab_RC/white_in'
#csv_path = 'C:/Users/user/Desktop/Colab_RC/white_in/interpolated.csv'
#df = pd.read_csv(csv_path, sep=",")



for i in range(5):
    index = random.randint(0,df.shape[0]-1)
    img_name = data_set + '/' + df.loc[index,'filename']
    #print(img_name)
    sample_image = cv2.imread(img_name)
    sample_image = cv2.cvtColor(sample_image,cv2.COLOR_RGB2BGR)
    sample_image_mod = cv2.resize(sample_image, (320,180)) #resize from 720x1280 to 180x320
    
    #plt.subplot(5,5,i+1)

    plt.imshow(sample_image_mod)

    layer_idx = utils.find_layer_idx(model, 'conv_5')

    grads = visualize_saliency(model, layer_idx, filter_indices=None, seed_input=sample_image_mod, backprop_modifier='guided')

    plt.imshow(grads, alpha = 0.6)
plt.savefig('RC_gt_2_hitmap_1.png')

# %%
plt.scatter(testY, preds)
plt.xlabel('True Values ')
plt.ylabel('Predictions ')
plt.axis('equal')
plt.axis('square')
plt.xlim([-3.75,3.75])
plt.ylim([-3.75,3.75])
plt.plot([-3.75, 3.75], [-3.75, 3.75], color='k', linestyle='-', linewidth=.1)

# %%
# View a Single Image 
# data_set = 'C:/Users/user/Desktop/Colab_RC/white_in'
# csv_path = 'C:/Users/user/Desktop/Colab_RC/white_in/interpolated.csv'
# df = pd.read_csv(csv_path, sep=",")

# Number of Images to Display
num_images = 4

# Display the images
i = 0
for i in range (i,num_images):
    index = random.randint(0,df.shape[0]-1)
    img_name = data_set + '/' + df.loc[index,'filename']
    sample_image = cv2.imread(img_name)
    sample_image = cv2.cvtColor(sample_image,cv2.COLOR_RGB2BGR)
    sample_image_mod = cv2.resize(sample_image, (320,180)) #resize from 720x1280 to 180x320
    plt.subplot(int(num_images/2),int(num_images/2),i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(sample_image_mod)
    layer_idx = utils.find_layer_idx(model, 'conv_5')
    grads = visualize_saliency(model, layer_idx, filter_indices=None, seed_input=sample_image_mod, backprop_modifier='guided')
    plt.imshow(grads, alpha = 0.6)
    i += 1
plt.savefig('model/RC_gt_2_hitmap_2.png')

# %%
plt.imshow(sample_image)

# %%
plt.imshow(grads)

# %% [markdown]
# # References:
# https://www.pyimagesearch.com/2019/01/28/keras-regression-and-cnns/
# https://www.pyimagesearch.com/2019/01/21/regression-with-keras/
# https://www.pyimagesearch.com/2018/12/24/how-to-use-keras-fit-and-fit_generator-a-hands-on-tutorial/
# https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l04c01_image_classification_with_cnns.ipynb#scrollTo=7MqDQO0KCaWS
#
# [Keras Image Processing Documentation](https://keras.io/preprocessing/image/)
